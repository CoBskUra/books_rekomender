# %%
import pandas as pd

# %%
books = pd.read_csv('books_orgin.csv', on_bad_lines='skip')
books
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %% [markdown]
# # 1 Dosotosowanie dazy danych do naszych potrzeb

# %% [markdown]
# ## 1.1 Usuwanie zbędnych kolumn

# %%
colums_to_delete = {"isbn", "isbn13", "text_reviews_count"}
for column_name in colums_to_delete:
    books.drop(column_name, inplace=True, axis=1)

# %%
books
# Out:
#        bookID                                              title  \
# 0           1  Harry Potter and the Half-Blood Prince (Harry ...
# 1           2  Harry Potter and the Order of the Phoenix (Har...
# 2           4  Harry Potter and the Chamber of Secrets (Harry...
# 3           5  Harry Potter and the Prisoner of Azkaban (Harr...
# 4           8  Harry Potter Boxed Set  Books 1-5 (Harry Potte...
# ...       ...                                                ...
# 11118   45631   Expelled from Eden: A William T. Vollmann Reader
# 11119   45633                        You Bright and Risen Angels
# 11120   45634                    The Ice-Shirt (Seven Dreams #1)
# 11121   45639                                        Poor People
# 11122   45641                        Las aventuras de Tom Sawyer
#
#                                                  authors  average_rating  \
# 0                             J.K. Rowling/Mary GrandPré            4.57
# ...

# %% [markdown]
# ## 1.2 Dodawanie kolumn

# %%
# gatunki
genres = open('genres.txt','r')
genres_list =[]
for line in genres:
    genres_list.append(line.strip())

genres_list
# Out:
# ['Fantasy',
#  'Science_Fiction',
#  'action___adventure',
#  'mystery',
#  'horror',
#  'thriller_and_suspense',
#  'historical_fiction',
#  'romance',
#  'women_s_fiction',
#  'lgbtq+',
#  'contemporary_fiction',
#  'literary_fiction',
#  'magical_realism',
#  'graphic_novel',
#  'short_story',
#  'young_adult',
#  'new_adult',
#  'for_Childrens',
#  'memoir_and_autobiography',
#  'biography',
#  'food_and_drink',
#  'art_and_photography',
#  'self_help',
#  'history',
#  'travel',
#  'true_crime',
#  'humor',
#  'essays',
#  'guide__how_to',
#  'religion_and_spirituality',
#  'humanities_and_social_sciences',
#  'parenting_and_families',
#  'short_story',
#  'graphic_novel',
#  'magical_realism',
#  'literary_fiction']
